# %%
! pip install json
# Out:
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json

# %%
import json

# %%
with open('episodes.json', 'r') as f:
    episodes = json.load(f)

# %%
episodes[0]
# Out:
# {'episode_id': 1,
#  'conversation_domain': 'education_ai',
#  'string_relevant_messages': ['I have been trying to build an AI system that can automatically generate multiple-choice questions from lecture notes, but I am struggling with ensuring the questions are actually meaningful and not just surface-level pattern matches.',
#   'One of the biggest issues I am facing is that the model tends to generate repetitive questions, even when I provide different chunks of input text. I suspect the prompt design might not be diverse enough.',
#   'Additionally, I want the system to evaluate the correctness of answers and provide explanations, but I am unsure how to structure the pipeline for both generation and evaluation.',
#   'I have experimented with retrieval-augmented generation, but sometimes the retrieved context is either irrelevant or too large, which affects the quality of the generated questions.',
#   'Ultimately, my goal is to build a study assistant that can adapt to different subjects and difficulty levels, but I need a more robust architecture to handle this variability.']}

# %%
with open('episodes.json', 'r') as f:
        episodes = json.load(f)

# %%
# Out:
# {'text': 'I have been trying to build an AI system that can automatically generate multiple-choice questions from lecture notes, but I am struggling with ensuring the questions are actually meaningful and not just surface-level pattern matches.',
#  'isRelevant': True}
